# %%
import pandas as pd
import numpy as np
from tqdm import tqdm

from pymorphy2 import MorphAnalyzer
from pymorphy2.tokenizers import simple_word_tokenize
from nltk.corpus import stopwords

import RAKE
from summa import keywords
from keybert import KeyBERT

from sklearn.metrics import precision_score, recall_score, f1_score

sw = stopwords.words('russian')
m = MorphAnalyzer()
r = Rake()

# %%
kw_model = KeyBERT('clips/mfaq')

# %% [markdown]
# ### 1. Подготовка корпуса
#
# Для сравнения я выбрала четыре статьи с cyberleninka, в каждой из которых есть раздел "ключевые слова":
# - М. С. Самарина: Символика волка в культуре: от Капитолийской волчицы до волка Франциска Ассизского
# - Ганьшина Г.В., Чаус Н.В.: Тамбовский волк. Символ или выдумка?
# - Карпенко Н.Т.: Экология волка
# - Е.А. Воробьевская, Д.В. Политов: О генетической дифферентации волка в Сибири

# %%
txts = []
for i in range(1, 5):
    p = r'волки/v' + str(i) + '.txt'
    with open(p, 'r', encoding='utf-8') as f:
        t = f.read()
        txts.append(t)

# %%
with open('keywords.txt', 'r', encoding = 'utf-8') as f:
    k = f.read()

# %%
k = k[2:].split('@@')
kw = [[k[i], k[i+1]] for i in range(0, len(k)-1, 2)]

# %%
def kw_prep(l):
    
    res = []
    lt = l.split(',')
    for i in lt:
        s = i.split()
        word_lemmas = []
        for w in s: # неясно, что делать со штуками типа "отстрел волков", получится "отстрел волк"
            word_lem = m.parse(w)[0].normal_form
            word_lemmas.append(word_lem)
        kword = ' '.join(word_lemmas)
        res.append(kword)

    return res

# %%
kw_list = [[kw_prep(i[0]), kw_prep(i[1])] for i in kw]

# %% [markdown]
# ### 2. Оценка пересечения и создание эталона

# %%
gold_kw = []
cr = 1
for i in kw_list:
    au_kw = i[0]
    my_kw = i[1]
    match_kw = set(au_kw).intersection(my_kw)
    pr = len(match_kw)/(len(au_kw)+len(my_kw)-len(match_kw))
    
    g = list(set(au_kw + my_kw))
    gold_kw.append(g)
    
    aup = ', '.join(au_kw)
    myp = ', '.join(my_kw)
    
    print(f'ТЕКСТ {cr}:')
    print(f'Токенов в тексте: {len(txts[cr-1].split())}')
    print(f'Оригинальные ключевые слова: {aup}')
    print(f'Мои ключевые слова: {myp}')
    print(f'Доля пересечения: {pr} ')
    print('\n')
    
    cr += 1
    

tot_len = [len(j.split()) for j in txts]
tl = sum(tot_len)
print(f'Общий объем корпуса: {tl} токенов')
# Out:
# ТЕКСТ 1:
# Токенов в тексте: 2811
# Оригинальные ключевые слова: средневековье, миф, архетип, мистика, ересь, менталитет, культура, религия
# Мои ключевые слова: волк, символ, символика, культура, миф, мифология, фольклор, легенда, животное, народ, культ, дьявол, религия, алхимия
# Доля пересечения: 0.15789473684210525
#
#
# ТЕКСТ 2:
# Токенов в тексте: 1855
# Оригинальные ключевые слова: народный художественный культура, тамбовский сувенир, скульптура тамбовский волк, легенда о тамбовский волк, возрождение, сохранение и развитие традиционный культура родный край
# Мои ключевые слова: народный искусство, творчество, тамбов, волк, тамбовский волк, выражение, легенда, народ
# Доля пересечения: 0.0
#
#
# ТЕКСТ 3:
# Токенов в тексте: 1775
# Оригинальные ключевые слова: волк, систематик, история, происхождение, морфология, экология, отношение человек к хищник, охота, истребление, регуляция численность, роль волк в биоценоз
# Мои ключевые слова: волк, экология, хищник, истребление, численность, охота, животноводство, регуляция численность, биоценоз, копытный, хозяйство
# Доля пересечения: 0.29411764705882354
#
#
# ТЕКСТ 4:
# Токенов в тексте: 2892
# Оригинальные ключевые слова: аллель, ген, гетерозиготность, днк-маркер, изменчивость, коэффициент нея, локус, микросателлит, популяция, таксономический статус
# Мои ключевые слова: днк, днк-маркер, аллель, локус, сибирь, популяция, микросателлитный маркер, гетерозиготность, аллельный разнообразие, приватный аллель, коэффициент нея, dn,
# Доля пересечения: 0.35294117647058826
#
#
# Общий объем корпуса: 9333 токенов

# %% [markdown]
# ### 3. Извлечение ключевых слов:

# %%
def normalize_text(text):
    
    lemmas = []
    for t in simple_word_tokenize(text):
        ls = m.parse(t)[0].normal_form
        lemmas.append(ls)
        
    return ' '.join(lemmas)

# %%
norm_txts = [normalize_text(i) for i in txts]

# %% [markdown]
# **Rake**

# %%
rake = RAKE.Rake(sw)

# %%
rake_all = []
for i in norm_txts:
    rake_list = rake.run(i, maxWords=3, minFrequency=2)
    rake_all.append([i[0] for i in rake_list])

# %% [markdown]
# **TextRank**

# %%
tr_all = []
for i in norm_txts:
    tr_list = keywords.keywords(i, language='russian', additional_stopwords=sw, scores=False)
    tr_all.append(tr_list.split())

# %% [markdown]
# **KeyBERT**

# %%
bert_all = []
for i in tqdm(range(len(txts))):
    bert_list = kw_model.extract_keywords(txts[i])
    bert_all.append(bert_list)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:47<00:00, 11.77s/it]

# %%
keybert_all = []
for i in bert_all:
    el = [j[0] for j in i]
    keybert_all.append(el)

# %% [markdown]
# ### 4. Морфосинтакические фильтры

# %%
full_kw = [rake_all, tr_all, keybert_all]

# %%
pos_cmb = [['NOUN'], ['NOUN', 'NOUN'], ['ADJF', 'NOUN']]

# %%
filtred_kw = []
for method in full_kw:
    mtd = []
    for text in method:
        text_kw = []
        for kwrd in text:
            pos_seq = []
            for subword in kwrd.split():
                pos_tag = m.parse(subword)[0].tag.POS
                pos_seq.append(pos_tag)
            if pos_seq in pos_cmb:
                text_kw.append(kwrd)
        mtd.append(text_kw)
    filtred_kw.append(mtd)

# %% [markdown]
# ### 5. Оценка качества

# %%
full_scores = {}
mtds = ['rake', 'text_rank', 'keybert']

# %%
def metrics_counter(kw, gold_kw=gold_kw, mtds=mtds):
    eps = 1**-5
    
    scores = {}
    for i in range(len(kw)): #methods level
        method_metrics = []

        for j in range(len(kw[i])): # texts level
            match = len(set(kw[i][j]).intersection(gold_kw[j]))
            prec = match/len(kw[i][j])
            rec = match/len(gold_kw[j])
            f1 = (2*prec*rec)/(prec+rec + eps)
            text_metrics = [prec, rec, f1]
            method_metrics.append(text_metrics)

        scores[mtds[i]] = method_metrics

    return scores

# %%
full_scores = metrics_counter(full_kw)
filtred_scores = metrics_counter(filtred_kw)

# %%
full_dfs = []
for i in full_scores:
    df = pd.DataFrame(full_scores[i], columns = ['precision', 'recall', 'f1'])
    full_dfs.append(df)

# %%
flr_dfs = []
for i in filtred_scores:
    df = pd.DataFrame(filtred_scores[i], columns = ['precision', 'recall', 'f1'])
    flr_dfs.append(df)

# %% [markdown]
# **без фильтров**

# %%
for i in range(len(mtds)):
    print(mtds[i])
    print(full_dfs[i])
    print('\n')
# Out:
# rake
#    precision    recall        f1
# 0   0.086207  0.263158  0.033625
# 1   0.090909  0.357143  0.044843
# 2   0.294118  0.588235  0.183824
# 3   0.039216  0.235294  0.014480
#
#
# text_rank
#    precision    recall        f1
# 0   0.055794  0.684211  0.043879
# 1   0.027027  0.285714  0.011765
# 2   0.071429  0.647059  0.053790
# 3   0.053846  0.411765  0.030256
#
#
# keybert
#    precision    recall        f1
# 0        0.4  0.105263  0.055944
# 1        0.2  0.071429  0.022472
# 2        0.0  0.000000  0.000000
# 3        0.0  0.000000  0.000000

# %% [markdown]
# **С фильтрами**

# %%
for i in range(len(mtds)):
    print(mtds[i])
    print(flr_dfs[i])
    print('\n')
# Out:
# rake
#    precision    recall        f1
# 0   0.142857  0.263158  0.053476
# 1   0.172414  0.357143  0.080515
# 2   0.360000  0.529412  0.201743
# 3   0.103448  0.176471  0.028526
#
#
# text_rank
#    precision    recall        f1
# 0   0.109244  0.684211  0.083354
# 1   0.047619  0.285714  0.020408
# 2   0.133333  0.588235  0.091116
# 3   0.096774  0.352941  0.047120
#
#
# keybert
#    precision    recall        f1
# 0       0.50  0.105263  0.065574
# 1       0.25  0.071429  0.027027
# 2       0.00  0.000000  0.000000
# 3       0.00  0.000000  0.000000

# %% [markdown]
# ### 6. Проблемы:
# - выделяются служебные и неполнозначные слова, обозначения и сокращения типа (г) и специальные символы -> дополнить список стоп-слов
# - не выделяются сложные именные группы типа "роль волка в биоценозе" выделяются только rake'ом (это нужно скорее учитывать при выборе метода, чем решать как проблему)
# - с моей человеческой точки зрения волк должен быть выделен во всех текстах, однако, keybert, например, не выделяет его вообще (вероятно, он слишком частотный(?)) Это полезная фича, если мы анализируем корпус текстов про волков и не хотим видеть волка в каждом списке, но в каком-то outer scope не очень. Можно попробовать как-то занижать частотность таких слов для работы с бертом.
# - выделяются слова с сомнительной степенью важности - "продолжать", "демонстрировать", но их можно отфильтровать, задав какой-нибудь порог для скора

# %%
for i in range(len(full_kw)): # вывод нефильтрованных слов для иллюстрации
    print(mtds[i])
    for j in full_kw[i]:
        print(j)
    print('\n')
# Out:
# rake
# ['парализовать взгляд волк', 'волк-оборотень', 'потусторонний мир', 'образ волк', 'капитолийский волчица', 'адский чудовище', 'скандинавский мифология', 'миф', 'волк', 'франциска', 'образ', 'также', 'мочь', 'волчица', 'волков', 'это', 'ересь', 'ад', 'встреча', 'текст', 'писать', 'лес', 'именно', 'ещё', 'литература', 'человек', 'который', 'культура', 'жестокость', 'время', 'данте', 'победа', 'ужасный', 'дьявол', 'губбио', 'описать', 'i', 'любовь', 'м', '\uf02d м', 'св', 'благородство', 'особенность', 'древнеислый', 'связанный', 'вольфганг', 'призрак', 'кроме', 'н', 'хотя', 'усложняться', 'иванов', 'l', 'assisi', '2', '\uf02d', '«', '4']
# ['издательский дом тгу', 'тамбовский волк', 'наука рф', 'уна-т', 'дата обращение', 'волк', 'сторона', 'скульптура', 'легенда', 'поэтому', 'ю', 'м-', 'город', 'год', 'тамбов', '« вой »', 'работа', 'tambov', 'ещё', 'г', 'символ', 'выдумка', 'сохранение', 'дерево', 'р', 'державин', 'возможно', 'народ', 'человек', 'прилегать', '130х91х23', 'известняк', 'ред', 'научий', 'конф', 'фёвр', '/ отв', 'григорьев', 'образец', 'гос', 'державин »', 'url', 'http', 'html', '/ / www', '«', '—', '10', '1992', '1998', '2', '2013', '06', '11', '2010']
# ['современный условие', 'зелёный сад', 'nina2012 @ yandex', 'дикий природа', 'год назад', 'зверь', 'популяция', 'человек', 'хищник', 'животное', 'численность', 'территория', 'заповедник', 'естественный', 'истребление', 'экосистема', 'регулирование', 'также', 'волк', 'экология', 'жизнь', 'вид', 'вырастить', 'систематик', 'происхождение', 'морфология', 'охота', 'охотиться', 'стая', 'район', 'копытный', 'н', '«', '»']
# ['качественный отличие популяция', 'показатель аллельный разнообразие', 'выборка вариант ii', 'предгорный выборка разделить', 'горно-таёжный', 'салаирский часть', 'северный тайга', 'показатель fst', 'равнинный степной', 'это связать', 'закономерность проявляться', 'горный тайга', 'каждый локус', 'предгорный лесостепной', 'коэффициент нея', 'кежемский район', 'группировка', 'таёжный', 'популяция', 'волк', 'выборка', 'тайга', 'минимальный —', 'район', 'аллель', 'степной', 'численность', 'малый —', 'саяна', 'условие', 'локус 2140', 'локус 2119', 'fst', 'алтай', 'предгорный', 'тува', 'нея', 'близкий', 'кежемский', 'dn', 'также', 'эвенкия', 'карта', 'a', 'вероятно', 'бурятия — 0', 'характерный', 'далее', 'политов', 'п', 'табла', 'больший', 'забайкалье', 'рис', 'предалтайский', 'возможно', 'следовательно', 'специфичный', 'указывать', 'количественный', 'степь', 'лесостепь', 'сходный', 'казахстан', '— м', 'наука', '5', '107', '2119', '2062', '2137', '2140', '2201', '1', '9', '8', '16', '667', '75', '2', '0', '3', '4', '073 0', '833', '109', '652', '801', '000 3', '739 0', '000 2', '000 8', '000 4', '000 6', '694 0', '803 0', '000 7', '615 0', '012 0', '000 0', '241 0', '241']
#
#
# text_rank
# ['символика', 'волк', 'небесный', 'волков', 'средневековье', 'франциска', 'это', 'образ', 'средневековый', 'литература', 'символ', 'м', 'капитолийский', 'волчица', 'также', 'который', 'мистик', 'франциск', 'свой', 'человек', 'животное', 'животный', 'мир', 'данте', 'св', 'текст', 'весь', 'этрусский', 'ii', 'i', 'очень', 'древний', 'the', 'известный', 'известно', 'легенда', 'являться', 'история', 'г', 'лес', 'ужас', 'часть', 'параллель', 'di', 'народ', 'статья', 'стать', 'имя', 'мифология', 'европа', 'культ', 'губбио', 'культура', 'слово', 'народный', 'мочь', 'творение', 'ещё', 'отрицательный', 'начало', 'описать', 'дантовый', 'ад', 'xiii', 'xii', 'часто', 'встречаться', 'иметь', 'амбивалентный', 'время', 'assisi', 'существовать', 'век', 'самый', 'жизнь', 'of', 'wolf', 'несколько', 'зло', 'составлять', 'язык', 'vita', 'именно', 'великий', 'зрение', 'совершить', 'множество', 'миф', 'рим', 'идти', 'зверь', 'оставаться', 'германский', 'италия', 'город', 'род', 'родиться', 'волчий', 'стая', 'кормить', 'серый', 'сера', 'дикий', 'встречать', 'представление', 'сын', 'п', 'архаический', 'согласно', 'затем', 'традиция', 'семья', 'положительный', 'светить', 'to', 'свобода', 'francesco', 'грааль', 'палатинский', 'знамение', 'слабый', 'древнеислый', 'адский', 'чудовище', 'усмирить', 'мария', 'дело', 'огромный', 'l', 'полуостров', 'францисканский', 'использоваться', 'использовать', 'агиография', 'агиограф', 'н', 'древнегерманский', 'бог', 'изображать', 'изображаться', 'legend', 'legenda', 'день', 'конец', 'свет', 'праздник', 'medieval', 'сказка', 'евразия', 'небольшой', 'ересь', 'святой', 'покровитель', 'первый', 'племя', 'партия', 'and', 'mythology', 'is', 'эдда', 'письменность', 'делла', 'необходимо', 'ромул', 'чистота', 'царь', 'амбивалентность', 'черта', 'чёрт', 'italian', 'italiano', 'пёс', 'правдоподобный', 'правдоподобно', 'магдалина', 'непризнанный', 'республика', 'значение', 'вольф', 'защитник', 'поэма', 'сергий', 'считать', 'считаться', 'среди', 'маска', 'взгляд', 'alto', 'medioevo', 'жестокость', 'жестокий', 'находить', 'враг', 'чингисхан', 'узбек', 'мифологизировать', 'мифологизированный', 'находиться', 'замок', 'синь', 'восток', 'gli', 'animali', 'смерть', 'порождение', 'утратить', 'страшный', 'памятник', 'хтонический', 'благородный', 'разбойник', 'робин', 'гуд', 'любовь', 'всё', 'изображение', 'собака', 'рассматривать', 'путь', 'beati', 'электронный', 'продолжение', 'алхимический', 'жить', 'житие', 'мистика', 'толкование', 'божественный', 'комедия', 'власть', 'studio', 'studi', 'белый']
# ['тамбовский', 'волк', 'волков', 'тамб', 'город', 'тамбов', 'г', 'tambov', 'скульптура', 'статья', 'стать', 'время', 'появиться', 'это', 'культура', 'человек', 'свой', 'российский', 'заниматься', 'занимать', 'россия', 'год', 'являться', 'который', 'очень', 'история', 'новый', 'крестьянин', 'поэтому', 'легенда', 'происхождение', 'крылатый', 'символ', 'материал', 'уникальный', 'традиция', 'древний', 'земля', 'and', 'legends', 'of', 'развитие', 'обращение', 'ru', 'край', 'скульптор', 'наш', 'фон', 'известность', 'м', 'чаус', 'н', 'обитать', 'известный', 'поэт', 'река', 'цна', 'роман', 'искусство', 'слово', 'разный', 'начаться', 'начало', 'место', 'житель', 'страна', 'сюда', 'тема', 'culture', 'промысл', 'музей', 'стая', 'памятник', 'народный', 'лесной', 'сильно', 'воевода', 'впо', 'постройка', 'крепость', 'однако', 'животное', 'область', 'татарин', 'путь', 'бог', 'молитвенник', 'назначить', 'уходить', 'помещичий', 'цениться', 'цена', 'научий', 'строительство', 'ещё', 'защита', 'ю', 'фильм', 'существовать', 'приходиться', 'приходить', 'возможно', 'день', 'проблема', 'выдумка', 'юг', 'дата', 'забытый', 'забытие', 'автор', 'возрождение', 'считать', 'считаться', 'sculpture', 'in', 'the', 'url', 'нападение', 'крымский', 'пустой', 'талон', 'михаил', 'особенный', 'особенность', 'сувенир', 'товарищ', 'волчий', 'местный', 'симеон', 'её', 'http', 'салычев', 'рассказовский', 'шоссе', 'присутствовать', 'стиль', 'век', 'малое', 'малый', 'сторона', 'условие', 'боборыкин', 'html', 'дуб', 'каждый', 'майка', 'орнамент', 'национальный']
# ['волков', 'экология', 'волк', 'это', 'хищник', 'животное', 'отношение', 'человек', 'численность', 'который', 'дикий', 'the', 'природный', 'заповедник', 'самый', 'являться', 'охотничий', 'постоянно', 'постоянный', 'экологический', 'экологически', 'корм', 'стать', 'роль', 'произойти', 'современный', 'иметь', 'весь', 'семь', 'вид', 'естественный', 'canis', 'lupus', 'среда', 'необходимость', 'необходимый', 'необходимо', 'копытный', 'ecology', 'of', 'a', 'wolf', 'год', 'природа', 'поведение', 'in', 'охота', 'охотиться', 'добыча', 'территория', 'мочь', 'шакал', 'копытное', 'присутствие', 'время', 'среди', 'следовать', 'изучение', 'популяция', 'истребление', 'ru', 'статья', 'анализироваться', 'дать', 'также', 'всё', 'лис', 'зверь', 'мнение', 'основный', 'основной', 'больший', 'большой', 'анализ', 'наиболее', 'многий', 'развитие', 'часто', 'слово', 'резать', 'зимний', 'хищный', 'млекопитающее', 'ущерб', 'элемент', 'многие', 'особенность', 'легко', 'лёгкий', 'условие', 'технический', 'важный', 'источник', 'домашний', 'способность', 'ограничиваться', 'санитар', 'шарбулак', 'разорять', 'способный', 'анализировать', 'зелёный', 'часть', 'передавать', 'информация', 'реакция', 'особенно', 'появиться', 'and', 'nina', 'сохранение', 'относительно', 'ограничивать', 'возможность', 'семейство', 'особь', 'особый', 'посещаться', 'посещать', 'оболочка', 'арбуз', 'семья', 'predator', 'predatory', 'жить', 'опыт', 'должный', 'история', 'охотник', 'сила', 'вынужденный', 'собака', 'результат', 'биолог', 'биология', 'демон', 'мрак', 'частичный', 'отстрел', 'тип', 'number', 'биоценоз', 'въёлчь', 'развиваться', 'происхождение', 'систематик', 'функционирование', 'цикл', 'идея', 'сквозь', 'период', 'отметить', 'капкан', 'влияние']
# ['волков', 'популяция', 'волк', 'сибирь', 'аллель', 'аллёля', 'выборка', 'локус', 'район', 'показатель', 'гетерозиготность', 'гетерозиготный', 'генетический', 'минимальный', 'значение', 'равнинно', 'равнинный', 'таёжный', 'средний', 'среднее', 'частый', 'часть', 'разнообразие', 'горно', 'горный', 'высокий', 'максимальный', 'изменчивость', 'количество', 'сходство', 'генетически', 'обусловить', 'алтайский', 'край', 'это', 'географический', 'распределение', 'иметь', 'иметься', 'сравнение', 'равнина', 'предгорный', 'лесостепной', 'тайга', 'fst', 'территориально', 'республика', 'весь', 'территория', 'общий', 'низкий', 'больший', 'большой', 'также', 'частота', 'таблица', 'проба', 'исследовать', 'численность', 'территориальный', 'группировка', 'год', 'аллельный', 'рис', 'уровень', 'предгорие', 'алтай', 'относительно', 'относительный', 'университет', 'наиболее', 'горнотаёжный', 'однако', 'экология', 'наблюдать', 'наблюдаться', 'анализ', 'степной', 'северный', 'ландшафтно', 'карта', 'dn', 'тува', 'ареал', 'внутривидовой', 'основа', 'наука', 'нея', 'южный', 'южно', 'закономерность', 'развитие', 'система', 'принцип', 'результат', 'характеризоваться', 'выявить', 'табла', 'вероятно', 'na', 'возможно', 'микросателлитный', 'маркер', 'малый', 'статус', 'характеристика', 'mellersh', 'поэтому', 'определённый', 'n', 'место', 'продолжать', 'ухудшаться', 'приватный', 'a', 'эффективный', 'число', 'лаборатория', 'программа', 'демонстрировать', 'he', 'стать', 'оба', 'полимеразный', 'цепной', 'реакция', 'общность', 'саяна', 'набор', 'алтухов']
#
#
# keybert
# ['символика', 'символики', 'symbolic', 'символа', 'легенда']
# ['легенд', 'культупамятник', 'легенда', 'symbol', 'символ']
# ['ecology', 'природы', 'биологи', 'history', 'биолог']
# ['биогеографической', 'структура', 'биологических', 'структуры', 'морфология']
